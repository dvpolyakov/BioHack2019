# %%
# %load_ext autoreload
# %load_ext rpy2.ipython

# %autoreload 2

import os
import glob
import re
import pandas as pd
import numpy as np
import itertools

import rpy2.robjects as ro
from rpy2.robjects.packages import importr
from rpy2.robjects import pandas2ri
pandas2ri.activate()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R -o load_annotations
# library(GEOquery)
# load_annotations <- function(datasetids) {
#     annotations=list()
#     GSEList <- list()
#     for(i in 1:length(datasetids)){
#         geo <- getGEO(datasetids[[i]], GSEMatrix=TRUE)
#         if(length(geo)>0){
#             annotations[[i]]<-pData(geo[[1]])
#         }
#     }
#     names(annotations)<-datasetids
#     return(annotations)
# }

# %%
import re

def catmapping(cat):
    cat=cat.replace("DLBCL","").replace("GCB.ABC.signature","")
    if(("ABC" in cat) or ("activated" in cat)):
        return "ABC"
    if(("GCB" in cat) or ("germinal center" in cat)):
        return "GCB"
    return "UNC"
    
def statusmapping(status, dead, alive):
    if(not status):
        return "UNC"
    if(dead in status or "1" in status):
        return "DEAD"
    if(alive in status or "0" in status):
        return "ALIVE"
    return "UNC"

def osmapping(os):
    if(not os):
        return np.NaN
    
    mul = 1
    if("year" in os):
        mul = 12
    if("day" in os):
        mul = 1/30
        
    rs = re.search("\d+\.\d+", os)
    if(rs):
        number = np.float(rs.group(0))*mul
    else:
        number=np.NaN
    
    return number
    
def convertcolumns(annotation, subtype_column, os_column, os_status, pfs_column, pfs_status,
                   dead_label="DEAD", alive_label="ALIVE"):
    
    if(os_column not in annotation):
        annotation["os_column"] = None
        os_column="os_column"
    if(os_status not in annotation):
        annotation["os_status"] = None
        os_status="os_status"
    if(pfs_column not in annotation):
        annotation["pfs_column"] = None
        pfs_column="pfs_column"
    if(pfs_status not in annotation):
        annotation["pfs_status"] = None
        pfs_status="pfs_status"
        
    annotation=annotation[[subtype_column,os_column,os_status,pfs_column,pfs_status]]
    annotation.columns=["type", "os", "os_status","pfs","pfs_status"]
    annotation.type = [catmapping(g) for g in annotation.type]
    annotation.type =  annotation.type.astype('category')

    annotation.os_status = [statusmapping(g, dead_label, alive_label)
                                      for g in annotation.os_status]
    annotation.os_status =  annotation.os_status.astype('category')
    annotation.pfs_status = [statusmapping(g, dead_label, alive_label)
                                      for g in annotation.pfs_status]
    annotation.pfs_status =  annotation.pfs_status.astype('category')

    
    annotation.os = [osmapping(g) for g in annotation.os]
    annotation.pfs = [osmapping(g) for g in annotation.pfs]
    
    return annotation

# %%
def process_annotations():
    datasets = pd.read_excel("data//B_cell_lymph_datasets_corrected.xlsx")
    datasets=datasets.fillna("")
    datasetids = list(datasets.Dataset_id)
    
    annotations = load_annotations(datasetids)
    
    annotations[16] = annotations[16][annotations[16]["characteristics_ch1.5"].apply(lambda x: ": BL" not in x)]
    annotations[19] = annotations[19][annotations[19]["characteristics_ch1.5"].apply(lambda x: ": BL" not in x)]
    annotations[6] = annotations[6][annotations[6]["characteristics_ch1.1"].apply(lambda x: ": MHG" not in x)]
    annotations[9] = annotations[9][annotations[9]["characteristics_ch1.1"].apply(lambda x: ": MHG" not in x)]
    i=0
    prannotations=list()
    for v in datasets.iterrows(): 
        typecolumn = v[1].subtype_column
        oscolumn = v[1].OS_column
        osstatuscolumn = v[1].OS_status_column
        pfscolumn = v[1].PFS_column
        pfsstatuscolumn = v[1].PFS_status_column
        prannotations.append(convertcolumns(annotations[i],typecolumn,oscolumn,osstatuscolumn,pfscolumn,pfsstatuscolumn))
        i=i+1

    processed = pd.concat(prannotations)
    return processed

# %%
process_annotations()
# Out:
# R[write to console]: Found 1 file(s)
#
# R[write to console]: GSE10846_series_matrix.txt.gz
#
# R[write to console]: Using locally cached version: /tmp/Rtmp6ukntQ/GSE10846_series_matrix.txt.gz
#
# R[write to console]: Parsed with column specification:
# cols(
#   .default = col_double(),
#   ID_REF = col_character()
# )
#
# R[write to console]: See spec(...) for full column specifications.
#
# R[write to console]: Using locally cached version of GPL570 found here:
# /tmp/Rtmp6ukntQ/GPL570.soft
#
# R[write to console]: Warning:
# R[write to console]:  62 parsing failures.
#   row     col           expected    actual         file
# 54614 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54615 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54616 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54617 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54618 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# ..... ....... .................. ......... ............
# See problems(...) for more details.
#
#
# R[write to console]: Found 2 file(s)
#
# R[write to console]: GSE11318-GPL570_series_matrix.txt.gz
#
# R[write to console]: Using locally cached version: /tmp/Rtmp6ukntQ/GSE11318-GPL570_series_matrix.txt.gz
#
# R[write to console]: Parsed with column specification:
# cols(
#   .default = col_double(),
#   ID_REF = col_character()
# )
#
# R[write to console]: See spec(...) for full column specifications.
#
# R[write to console]: Using locally cached version of GPL570 found here:
# /tmp/Rtmp6ukntQ/GPL570.soft
#
# R[write to console]: Warning:
# R[write to console]:  62 parsing failures.
#   row     col           expected    actual         file
# 54614 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54615 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54616 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54617 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54618 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# ..... ....... .................. ......... ............
# See problems(...) for more details.
#
#
# R[write to console]: GSE11318-GPL6400_series_matrix.txt.gz
#
# R[write to console]: Using locally cached version: /tmp/Rtmp6ukntQ/GSE11318-GPL6400_series_matrix.txt.gz
#
# R[write to console]: Parsed with column specification:
# cols(
#   .default = col_double(),
#   ID_REF = col_character()
# )
#
# R[write to console]: See spec(...) for full column specifications.
#
# R[write to console]: Using locally cached version of GPL6400 found here:
# /tmp/Rtmp6ukntQ/GPL6400.soft
#
# R[write to console]: Found 1 file(s)
#
# R[write to console]: GSE4475_series_matrix.txt.gz
#
# R[write to console]: Using locally cached version: /tmp/Rtmp6ukntQ/GSE4475_series_matrix.txt.gz
#
# R[write to console]: Parsed with column specification:
# cols(
#   .default = col_double(),
#   ID_REF = col_character()
# )
#
# R[write to console]: See spec(...) for full column specifications.
#
# R[write to console]: Using locally cached version of GPL96 found here:
# /tmp/Rtmp6ukntQ/GPL96.soft
#
# R[write to console]: Warning:
# R[write to console]:  68 parsing failures.
#   row     col           expected    actual         file
# 22216 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 22217 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 22218 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 22219 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 22220 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# ..... ....... .................. ......... ............
# See problems(...) for more details.
#
#
# R[write to console]: Found 1 file(s)
#
# R[write to console]: GSE93984_series_matrix.txt.gz
#
# R[write to console]: Using locally cached version: /tmp/Rtmp6ukntQ/GSE93984_series_matrix.txt.gz
#
# R[write to console]: Parsed with column specification:
# cols(
#   .default = col_double(),
#   ID_REF = col_character()
# )
#
# R[write to console]: See spec(...) for full column specifications.
#
# R[write to console]: Using locally cached version of GPL570 found here:
# /tmp/Rtmp6ukntQ/GPL570.soft
#
# R[write to console]: Warning:
# R[write to console]:  62 parsing failures.
#   row     col           expected    actual         file
# 54614 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54615 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54616 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54617 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54618 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# ..... ....... .................. ......... ............
# See problems(...) for more details.
#
#
# R[write to console]: Found 1 file(s)
#
# R[write to console]: GSE19246_series_matrix.txt.gz
#
# R[write to console]: Using locally cached version: /tmp/Rtmp6ukntQ/GSE19246_series_matrix.txt.gz
#
# R[write to console]: Parsed with column specification:
# cols(
#   .default = col_double(),
#   ID_REF = col_character()
# )
#
# R[write to console]: See spec(...) for full column specifications.
#
# R[write to console]: Using locally cached version of GPL570 found here:
# /tmp/Rtmp6ukntQ/GPL570.soft
#
# R[write to console]: Warning:
# R[write to console]:  62 parsing failures.
#   row     col           expected    actual         file
# 54614 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54615 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54616 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54617 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54618 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# ..... ....... .................. ......... ............
# See problems(...) for more details.
#
#
# R[write to console]: Found 1 file(s)
#
# R[write to console]: GSE22470_series_matrix.txt.gz
#
# R[write to console]: Using locally cached version: /tmp/Rtmp6ukntQ/GSE22470_series_matrix.txt.gz
#
# R[write to console]: Parsed with column specification:
# cols(
#   .default = col_double(),
#   ID_REF = col_character()
# )
#
# R[write to console]: See spec(...) for full column specifications.
#
# R[write to console]: Using locally cached version of GPL96 found here:
# /tmp/Rtmp6ukntQ/GPL96.soft
#
# R[write to console]: Warning:
# R[write to console]:  68 parsing failures.
#   row     col           expected    actual         file
# 22216 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 22217 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 22218 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 22219 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 22220 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# ..... ....... .................. ......... ............
# See problems(...) for more details.
#
#
# R[write to console]: Found 1 file(s)
#
# R[write to console]: GSE117556_series_matrix.txt.gz
#
# R[write to console]: Using locally cached version: /tmp/Rtmp6ukntQ/GSE117556_series_matrix.txt.gz
#
# R[write to console]: Parsed with column specification:
# cols(
#   .default = col_double(),
#   ID_REF = col_character()
# )
#
# R[write to console]: See spec(...) for full column specifications.
#
# R[write to console]: Using locally cached version of GPL14951 found here:
# /tmp/Rtmp6ukntQ/GPL14951.soft
#
# R[write to console]: Found 1 file(s)
#
# R[write to console]: GSE31312_series_matrix.txt.gz
#
# R[write to console]: Using locally cached version: /tmp/Rtmp6ukntQ/GSE31312_series_matrix.txt.gz
#
# R[write to console]: Parsed with column specification:
# cols(
#   .default = col_double(),
#   ID_REF = col_character()
# )
#
# R[write to console]: See spec(...) for full column specifications.
#
# R[write to console]: Using locally cached version of GPL570 found here:
# /tmp/Rtmp6ukntQ/GPL570.soft
#
# R[write to console]: Warning:
# R[write to console]:  62 parsing failures.
#   row     col           expected    actual         file
# 54614 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54615 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54616 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54617 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54618 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# ..... ....... .................. ......... ............
# See problems(...) for more details.
#
#
# R[write to console]: Found 1 file(s)
#
# R[write to console]: GSE32918_series_matrix.txt.gz
#
# R[write to console]: Using locally cached version: /tmp/Rtmp6ukntQ/GSE32918_series_matrix.txt.gz
#
# R[write to console]: Parsed with column specification:
# cols(
#   .default = col_double(),
#   ID_REF = col_character()
# )
#
# R[write to console]: See spec(...) for full column specifications.
#
# R[write to console]: Using locally cached version of GPL8432 found here:
# /tmp/Rtmp6ukntQ/GPL8432.soft
# R[write to console]: Found 1 file(s)
#
# R[write to console]: GSE117556_series_matrix.txt.gz
#
# R[write to console]: Using locally cached version: /tmp/Rtmp6ukntQ/GSE117556_series_matrix.txt.gz
#
# R[write to console]: Parsed with column specification:
# cols(
#   .default = col_double(),
#   ID_REF = col_character()
# )
#
# R[write to console]: See spec(...) for full column specifications.
#
# R[write to console]: Using locally cached version of GPL14951 found here:
# /tmp/Rtmp6ukntQ/GPL14951.soft
#
# R[write to console]: Found 1 file(s)
#
# R[write to console]: GSE99276_series_matrix.txt.gz
#
# R[write to console]: Using locally cached version: /tmp/Rtmp6ukntQ/GSE99276_series_matrix.txt.gz
#
# R[write to console]: Parsed with column specification:
# cols(
#   ID_REF = col_double(),
#   GSM2640279 = col_double(),
#   GSM2640280 = col_double(),
#   GSM2640281 = col_double(),
#   GSM2640282 = col_double(),
#   GSM2640283 = col_double(),
#   GSM2640284 = col_double(),
#   GSM2640285 = col_double(),
#   GSM2640286 = col_double()
# )
#
# R[write to console]: Using locally cached version of GPL4133 found here:
# /tmp/Rtmp6ukntQ/GPL4133.soft
#
# R[write to console]: Found 1 file(s)
#
# R[write to console]: GSE70637_series_matrix.txt.gz
#
# R[write to console]: Using locally cached version: /tmp/Rtmp6ukntQ/GSE70637_series_matrix.txt.gz
#
# R[write to console]: Parsed with column specification:
# cols(
#   ID_REF = col_character(),
#   GSM1815505 = col_double(),
#   GSM1815507 = col_double(),
#   GSM1815508 = col_double(),
#   GSM1815510 = col_double()
# )
#
# R[write to console]: Using locally cached version of GPL17077 found here:
# /tmp/Rtmp6ukntQ/GPL17077.soft
#
# R[write to console]: Found 1 file(s)
#
# R[write to console]: GSE74266_series_matrix.txt.gz
#
# R[write to console]: Using locally cached version: /tmp/Rtmp6ukntQ/GSE74266_series_matrix.txt.gz
#
# R[write to console]: Parsed with column specification:
# cols(
#   .default = col_double(),
#   ID_REF = col_character()
# )
#
# R[write to console]: See spec(...) for full column specifications.
#
# R[write to console]: Using locally cached version of GPL570 found here:
# /tmp/Rtmp6ukntQ/GPL570.soft
#
# R[write to console]: Warning:
# R[write to console]:  62 parsing failures.
#   row     col           expected    actual         file
# 54614 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54615 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54616 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54617 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54618 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# ..... ....... .................. ......... ............
# See problems(...) for more details.
#
#
# R[write to console]: Found 1 file(s)
#
# R[write to console]: GSE64586_series_matrix.txt.gz
#
# R[write to console]: Using locally cached version: /tmp/Rtmp6ukntQ/GSE64586_series_matrix.txt.gz
#
# R[write to console]: Parsed with column specification:
# cols(
#   .default = col_double()
# )
#
# R[write to console]: See spec(...) for full column specifications.
#
# R[write to console]: Using locally cached version of GPL4133 found here:
# /tmp/Rtmp6ukntQ/GPL4133.soft
#
# R[write to console]: Found 1 file(s)
#
# R[write to console]: GSE71526_series_matrix.txt.gz
#
# R[write to console]: Using locally cached version: /tmp/Rtmp6ukntQ/GSE71526_series_matrix.txt.gz
#
# R[write to console]: Parsed with column specification:
# cols(
#   .default = col_double(),
#   ID_REF = col_character()
# )
#
# R[write to console]: See spec(...) for full column specifications.
#
# R[write to console]: Using locally cached version of GPL6480 found here:
# /tmp/Rtmp6ukntQ/GPL6480.soft
#
# R[write to console]: Warning:
# R[write to console]:  94 parsing failures.
#   row          col           expected actual         file
# 41001 CONTROL_TYPE 1/0/T/F/TRUE/FALSE    pos literal data
# 41002 CONTROL_TYPE 1/0/T/F/TRUE/FALSE    pos literal data
# 41003 CONTROL_TYPE 1/0/T/F/TRUE/FALSE    pos literal data
# 41004 CONTROL_TYPE 1/0/T/F/TRUE/FALSE    pos literal data
# 41005 CONTROL_TYPE 1/0/T/F/TRUE/FALSE    pos literal data
# ..... ............ .................. ...... ............
# See problems(...) for more details.
#
#
# R[write to console]: Found 1 file(s)
#
# R[write to console]: GSE64555_series_matrix.txt.gz
#
# R[write to console]: Using locally cached version: /tmp/Rtmp6ukntQ/GSE64555_series_matrix.txt.gz
#
# R[write to console]: Parsed with column specification:
# cols(
#   .default = col_double(),
#   ID_REF = col_character()
# )
#
# R[write to console]: See spec(...) for full column specifications.
#
# R[write to console]: Using locally cached version of GPL570 found here:
# /tmp/Rtmp6ukntQ/GPL570.soft
#
# R[write to console]: Warning:
# R[write to console]:  62 parsing failures.
#   row     col           expected    actual         file
# 54614 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54615 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54616 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54617 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54618 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# ..... ....... .................. ......... ............
# See problems(...) for more details.
#
#
# R[write to console]: Found 1 file(s)
#
# R[write to console]: GSE17372_series_matrix.txt.gz
#
# R[write to console]: Using locally cached version: /tmp/Rtmp6ukntQ/GSE17372_series_matrix.txt.gz
#
# R[write to console]: Parsed with column specification:
# cols(
#   ID_REF = col_character(),
#   GSM429903 = col_double(),
#   GSM429904 = col_double(),
#   GSM429905 = col_double(),
#   GSM429906 = col_double(),
#   GSM429907 = col_double(),
#   GSM429908 = col_double(),
#   GSM429909 = col_double(),
#   GSM429910 = col_double(),
#   GSM429911 = col_double(),
#   GSM429912 = col_double(),
#   GSM429913 = col_double(),
#   GSM429914 = col_double(),
#   GSM429915 = col_double(),
#   GSM429916 = col_double(),
#   GSM429917 = col_double(),
#   GSM429918 = col_double(),
#   GSM429919 = col_double()
# )
#
# R[write to console]: Using locally cached version of GPL570 found here:
# /tmp/Rtmp6ukntQ/GPL570.soft
#
# R[write to console]: Warning:
# R[write to console]:  62 parsing failures.
#   row     col           expected    actual         file
# 54614 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54615 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54616 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54617 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54618 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# ..... ....... .................. ......... ............
# See problems(...) for more details.
#
#
# R[write to console]: Found 1 file(s)
#
# R[write to console]: GSE23967_series_matrix.txt.gz
#
# R[write to console]: Using locally cached version: /tmp/Rtmp6ukntQ/GSE23967_series_matrix.txt.gz
#
# R[write to console]: Parsed with column specification:
# cols(
#   .default = col_double(),
#   ID_REF = col_character()
# )
#
# R[write to console]: See spec(...) for full column specifications.
#
# R[write to console]: Using locally cached version of GPL6604 found here:
# /tmp/Rtmp6ukntQ/GPL6604.soft
#
# R[write to console]: Found 1 file(s)
#
# R[write to console]: GSE23501_series_matrix.txt.gz
#
# R[write to console]: Using locally cached version: /tmp/Rtmp6ukntQ/GSE23501_series_matrix.txt.gz
#
# R[write to console]: Parsed with column specification:
# cols(
#   .default = col_double(),
#   ID_REF = col_character()
# )
#
# R[write to console]: See spec(...) for full column specifications.
#
# R[write to console]: Using locally cached version of GPL570 found here:
# /tmp/Rtmp6ukntQ/GPL570.soft
#
# R[write to console]: Warning:
# R[write to console]:  62 parsing failures.
#   row     col           expected    actual         file
# 54614 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54615 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54616 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54617 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54618 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# ..... ....... .................. ......... ............
# See problems(...) for more details.
#
#
# R[write to console]: Found 1 file(s)
#
# R[write to console]: GSE17189_series_matrix.txt.gz
#
# R[write to console]: Using locally cached version: /tmp/Rtmp6ukntQ/GSE17189_series_matrix.txt.gz
#
# R[write to console]: Parsed with column specification:
# cols(
#   ID_REF = col_character(),
#   GSM429903 = col_double(),
#   GSM429904 = col_double(),
#   GSM429905 = col_double(),
#   GSM429906 = col_double(),
#   GSM429907 = col_double(),
#   GSM429908 = col_double(),
#   GSM429909 = col_double(),
#   GSM429910 = col_double(),
#   GSM429911 = col_double(),
#   GSM429912 = col_double(),
#   GSM429913 = col_double(),
#   GSM429914 = col_double(),
#   GSM429915 = col_double(),
#   GSM429916 = col_double(),
#   GSM429917 = col_double(),
#   GSM429918 = col_double(),
#   GSM429919 = col_double()
# )
# R[write to console]: Using locally cached version of GPL570 found here:
# /tmp/Rtmp6ukntQ/GPL570.soft
#
# R[write to console]: Warning:
# R[write to console]:  62 parsing failures.
#   row     col           expected    actual         file
# 54614 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54615 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54616 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54617 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# 54618 SPOT_ID 1/0/T/F/TRUE/FALSE --Control literal data
# ..... ....... .................. ......... ............
# See problems(...) for more details.
#           type      os os_status    pfs pfs_status
# GSM274895  GCB   32.16      DEAD    NaN        UNC
# GSM274896  GCB    9.84      DEAD    NaN        UNC
# GSM274897  ABC   30.48      DEAD    NaN        UNC
# GSM274898  ABC  116.04     ALIVE    NaN        UNC
# GSM274899  ABC   57.96     ALIVE    NaN        UNC
# GSM274900  ABC   86.52     ALIVE    NaN        UNC
# GSM274901  ABC    0.60      DEAD    NaN        UNC
# GSM274902  ABC  121.68     ALIVE    NaN        UNC
# GSM274903  GCB   15.96      DEAD    NaN        UNC
# GSM274904  GCB  184.92     ALIVE    NaN        UNC
# GSM274905  GCB   86.64     ALIVE    NaN        UNC
# GSM274906  GCB   49.08     ALIVE    NaN        UNC
# GSM274907  GCB  109.32      DEAD    NaN        UNC
# GSM274908  GCB    3.96      DEAD    NaN        UNC
# GSM274909  GCB  170.88     ALIVE    NaN        UNC
# GSM274910  GCB  106.32     ALIVE    NaN        UNC
# GSM274911  GCB   47.16      DEAD    NaN        UNC
# GSM274912  GCB    1.80      DEAD    NaN        UNC
# GSM274913  UNC   46.80     ALIVE    NaN        UNC
# GSM274914  ABC     NaN     ALIVE    NaN        UNC
# GSM274915  ABC    3.36      DEAD    NaN        UNC
# GSM274916  GCB  175.08     ALIVE    NaN        UNC
# GSM274917  ABC   66.84      DEAD    NaN        UNC
# GSM274918  GCB   83.28      DEAD    NaN        UNC
# GSM274919  ABC    3.00      DEAD    NaN        UNC
# GSM274920  ABC   79.68      DEAD    NaN        UNC
# GSM274921  ABC   27.72      DEAD    NaN        UNC
# GSM274922  GCB    2.76      DEAD    NaN        UNC
# GSM274923  ABC    8.52      DEAD    NaN        UNC
# GSM274924  ABC   15.72      DEAD    NaN        UNC
# ...        ...     ...       ...    ...        ...
# GSM575688  GCB   11.16       UNC  11.16        UNC
# GSM575689  GCB   15.00       UNC  15.00        UNC
# GSM575690  ABC    8.16       UNC   8.16        UNC
# GSM575691  ABC   11.88       UNC  11.88        UNC
# GSM575692  GCB    5.16       UNC   5.16        UNC
# GSM575693  GCB   18.48       UNC  18.48        UNC
# GSM575694  GCB   11.88       UNC  11.88        UNC
# GSM575695  GCB   12.24       UNC  12.24        UNC
# GSM575696  ABC   13.68       UNC  13.68        UNC
# GSM575697  GCB   11.88       UNC  11.88        UNC
# GSM575698  GCB    8.88       UNC   8.88        UNC
# GSM575699  GCB    6.72       UNC   6.72        UNC
# GSM575700  GCB    8.76       UNC   8.76        UNC
# GSM575701  GCB    9.48       UNC   9.48        UNC
# GSM575702  ABC    7.68       UNC   7.68        UNC
# GSM575703  ABC   18.00       UNC    NaN       DEAD
# GSM429904  GCB     NaN       UNC    NaN        UNC
# GSM429905  UNC     NaN       UNC    NaN        UNC
# GSM429906  UNC     NaN       UNC    NaN        UNC
# GSM429907  UNC     NaN       UNC    NaN        UNC
# GSM429908  ABC     NaN       UNC    NaN        UNC
# GSM429909  UNC     NaN       UNC    NaN        UNC
# GSM429911  GCB     NaN       UNC    NaN        UNC
# GSM429912  UNC     NaN       UNC    NaN        UNC
# GSM429913  ABC     NaN       UNC    NaN        UNC
# GSM429914  ABC     NaN       UNC    NaN        UNC
# GSM429916  GCB     NaN       UNC    NaN        UNC
# GSM429917  ABC     NaN       UNC    NaN        UNC
# GSM429918  UNC     NaN       UNC    NaN        UNC
# GSM429919  UNC     NaN       UNC    NaN        UNC
#
# [4145 rows x 5 columns]
